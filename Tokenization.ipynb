# %%
import pandas as pd
import os
from eunjeon import Mecab
from konlpy.tag import Okt
from konlpy.tag import Kkma
from konlpy.tag import Komoran

# %%
df = pd.read_csv("movies.csv")
df
# Out:
#                       title  \
# 0                      늑대아이
# 1                      범죄도시
# 2                      콘스탄틴
# 3                  약속의 네버랜드
# 4                 나만이 없는 거리
# ...                     ...
# 1458                여대생 기숙사
# 1459                     바람
# 1460                   그린 북
# 1461  판의 미로 - 오필리아와 세 개의 열쇠
# 1462          이 멋진 세계에 축복을!
#
#                                                   story  rating         genre  \
# 0     평범한 여대생 하나는 우연히 평범한 사람이 아닌 늑대인간과 사랑에 빠지게 된다. 하...     4.0   판타지 · 애니메이션
# 1     주먹으로 도시의 평화를 유지해온 형사 마석도와 반장 전일만이 이끄는 강력반은 신흥 ...     4.0       범죄 · 액션
# 2     콘스탄틴은 천국과 지옥을 넘나들며 세상의 악을 지옥으로 돌려보낸다. 어느 날, 전투...     3.9      판타지 · 액션
# 3     부모가 없는 아이들이 함께 살아가는 그레이스 필드 하우스. 세상과 단절된 채 살아가...     4.3   애니메이션 · 판타지
# 4     '리바이벌'이라는 시간 이동 능력을 가진 사토루. 그는 자신이 과거에 지나친 사건이...     4.1  애니메이션 · 미스터리
# ...                                                 ...     ...           ...
# 1458  메간이 실종된 후 1년이 지난 어느 날, 그녀의 친구 클레어, 제시카, 캐시디, 척...     2.2     공포 · 미스터리
# 1459  부산일대에서 알아주는 악명 높은 학교, 광춘상고의 명성을 증명하듯 조회시간에 ‘불법...     3.9      드라마 · 액션
# 1460  입담과 주먹만 믿고 살아가던 토니는 천재 피아니스트 셜리 박사의 운전기사로 고용된다...     4.2     코미디 · 드라마
# 1461  오필리아는 만삭인 엄마와 군인인 새아버지를 따라 부대 저택으로 이사를 간다. 신비한...     3.7     드라마 · 판타지
# 1462  게임을 사랑하는 은둔형 외톨이 소년, 사토 카즈마의 인생은 너무나도 허무하게 그 막...     4.0   애니메이션 · 판타지
#
#              tag     region   year
# 0       사랑 · 영상미         일본  2012년
# 1           폭력적인         한국  2017년
# 2        워너 브라더스    미국 · 독일  2005년
# 3           스릴있는         일본  2019년
# 4        no_tags         일본  2016년
# ...          ...        ...    ...
# 1458          살인         미국  2009년
# 1459         연기력         한국  2009년
# 1460  연기력 · 희망적인         미국  2018년
# 1461   완성도 · 어두운  멕시코 · 스페인  2006년
# 1462     no_tags         일본  2016년
#
# [1463 rows x 7 columns]

# %%
mecab = Mecab("C:/mecab/mecab-ko-dic")
text = df.iloc[6,:]
# print(df['title'][6])
print(text)
# a = mecab.pos(text)
# print(a)
# a = mecab.morphs(text)
# print(a)
# Out:
# title                                                   인셉션
# story     타인의 꿈에 들어가 생각을 훔칠 수 있는 가까운 미래. 꿈의 보안 프로그래머 코브는...
# rating                                                  4.4
# genre                                               액션 · 모험
# tag                                              강렬한 · 퍼포먼스
# region                                              미국 · 영국
# year                                                  2010년
# Name: 6, dtype: object
