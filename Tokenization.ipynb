# %%
import pandas as pd
from eunjeon import Mecab
from konlpy.tag import Okt
from konlpy.tag import Kkma
from konlpy.tag import Komoran

# %%
df = pd.read_csv("movies.csv")
df
# Out:
#             title                                              story  rating  \
# 0            늑대아이  평범한 여대생 하나는 우연히 평범한 사람이 아닌 늑대인간과 사랑에 빠지게 된다. 하...     4.0
# 1            범죄도시  주먹으로 도시의 평화를 유지해온 형사 마석도와 반장 전일만이 이끄는 강력반은 신흥 ...     4.0
# 2            콘스탄틴  콘스탄틴은 천국과 지옥을 넘나들며 세상의 악을 지옥으로 돌려보낸다. 어느 날, 전투...     3.9
# 3        약속의 네버랜드  부모가 없는 아이들이 함께 살아가는 그레이스 필드 하우스. 세상과 단절된 채 살아가...     4.3
# 4       나만이 없는 거리  '리바이벌'이라는 시간 이동 능력을 가진 사토루. 그는 자신이 과거에 지나친 사건이...     4.1
# ...           ...                                                ...     ...
# 1272       시크릿 가든  무술감독을 꿈꾸는 스턴트우먼 길라임과 까칠한 백화점 사장 김주원. 의도치 않게 영혼...     4.0
# 1273    티파니에서 아침을  신분 상승을 꿈꾸며 티파니 보석상을 활보하는 여인 홀리. 같은 아파트에 사는 가난한...     3.8
# 1274  신의 선물 - 14일  유괴범에게 딸을 잃은지 14일 전으로 타임워프 된 방송작가 수현. 14일 안에 범인...     3.9
# 1275        더 콘서트  유대인 연주자들을 몰아내라는 당의 지시를 어겨 지휘를 그만두게 된 안드레이. 음악에...     3.5
# 1276         록키 3  승승장구하던 록키는 자만심과 매너리즘에 빠져 관장 믹키와 다툰다. 강력한 복서 클러...     3.5
#
#              genre         tag      region   year
# 0      판타지 · 애니메이션    사랑 · 영상미          일본  2012년
# 1          범죄 · 액션        폭력적인          한국  2017년
# 2         판타지 · 액션     워너 브라더스     미국 · 독일  2005년
# 3      애니메이션 · 판타지        스릴있는          일본  2019년
# 4     애니메이션 · 미스터리     no_tags          일본  2016년
# ...            ...         ...         ...    ...
# 1272  로맨스 · 로맨틱코미디     no_tags          한국  2010년
# 1273     코미디 · 로맨스  완성도 · 퍼포먼스          미국  1961년
# 1274    미스터리 · 스릴러         연기력          한국  2014년
# 1275     코미디 · 드라마        퍼포먼스  프랑스 · 이탈리아  2009년
# 1276     드라마 · 스포츠  치열한 · 퍼포먼스    미국 · 캐나다  1982년
#
# [1277 rows x 7 columns]

# %%
mecab = Mecab()
text = "아버지가방에들어가신다"
a = mecab.pos(text)
print(a)
a = mecab.morphs(text)
print(a)
# Out:
# [('아버지', 'NNG'), ('가방', 'NNG'), ('에', 'JKB'), ('들어가', 'VV'), ('신다', 'EP+EC')]
# ['아버지', '가방', '에', '들어가', '신다']
