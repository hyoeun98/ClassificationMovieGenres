# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import re

# %%
data = pd.read_csv('watcha_crawling.csv')
data
# Out:
#           title                                              story  \
# 0          늑대아이  평범한 여대생 하나는 우연히 평범한 사람이 아닌 늑대인간과 사랑에 빠지게 된다. 하...
# 1          범죄도시  주먹으로 도시의 평화를 유지해온 형사 마석도와 반장 전일만이 이끄는 강력반은 신흥 ...
# 2          콘스탄틴  콘스탄틴은 천국과 지옥을 넘나들며 세상의 악을 지옥으로 돌려보낸다. 어느 날, 전투...
# 3      약속의 네버랜드  부모가 없는 아이들이 함께 살아가는 그레이스 필드 하우스. 세상과 단절된 채 살아가...
# 4     나만이 없는 거리  '리바이벌'이라는 시간 이동 능력을 가진 사토루. 그는 자신이 과거에 지나친 사건이...
# ...         ...                                                ...
# 2752    LA 컨피덴셜  어느 날 카페에서 퇴직 형사 스탠스를 포함한 일곱 명이 목숨을 잃는다. 이내 신참 ...
# 2753     프랑켄슈타인  1794년, 북극으로 향하던 월튼 선장은 얼음구덩이에서 빅터 프랑켄슈타인을 구조한다...
# 2754     데블스 더블  가족을 해하겠다는 위협 때문에 우다이의 대역을 하게 된 라티프는 자신이 충성을 다했...
# 2755        현기증  순임은 큰 딸 영희와 사위 상호 그리고 고등학생인 작은 딸 꽃잎과 살고 있다. 오랜...
# 2756       록키 3  승승장구하던 록키는 자만심과 매너리즘에 빠져 관장 믹키와 다툰다. 강력한 복서 클러...
#
#                       rating  \
# 0     예상 별점\n3.9\n평균 별점\n4.0
# 1     예상 별점\n3.5\n평균 별점\n4.0
# 2     예상 별점\n3.5\n평균 별점\n3.9
# 3     예상 별점\n4.2\n평균 별점\n4.3
# 4     예상 별점\n4.1\n평균 별점\n4.1
# ...                      ...
# 2752  예상 별점\n2.8\n평균 별점\n3.7
# 2753  예상 별점\n3.0\n평균 별점\n3.4
# 2754  예상 별점\n2.5\n평균 별점\n3.4
# 2755  예상 별점\n2.9\n평균 별점\n3.5
# 2756  예상 별점\n1.9\n평균 별점\n3.5
#
#                                                    info
# 0     개요  판타지 · 애니메이션   |   사랑 · 영상미   |   일본   |   ...
# 1          개요  범죄 · 액션   |   폭력적인   |   한국   |    2017년
# 2     개요  판타지 · 액션   |   워너 브라더스   |   미국 · 독일   |  ...
# 3      개요  애니메이션 · 판타지   |   스릴있는   |   일본   |    2019년
# 4                개요  애니메이션 · 미스터리   |   일본   |    2016년
# ...                                                 ...
# 2752  개요  범죄 · 드라마   |   연기력 · 완성도   |   미국   |    1...
# 2753  개요  공포 · 드라마   |   연기력 · 완성도   |   미국 · 일본   |...
# 2754  개요  드라마 · 스릴러   |   연기력 · 강렬한   |   벨기에 · 네덜란드...
# 2755      개요  드라마   |   연기력 · 완성도   |   한국   |    2014년
# 2756  개요  드라마 · 스포츠   |   치열한 · 퍼포먼스   |   미국 · 캐나다 ...
#
# [2757 rows x 4 columns]

# %%
df = data.drop_duplicates(['title'],ignore_index=True)
df = df.dropna(how="any")
df
# Out:
#             title                                              story  \
# 0            늑대아이  평범한 여대생 하나는 우연히 평범한 사람이 아닌 늑대인간과 사랑에 빠지게 된다. 하...
# 1            범죄도시  주먹으로 도시의 평화를 유지해온 형사 마석도와 반장 전일만이 이끄는 강력반은 신흥 ...
# 2            콘스탄틴  콘스탄틴은 천국과 지옥을 넘나들며 세상의 악을 지옥으로 돌려보낸다. 어느 날, 전투...
# 3        약속의 네버랜드  부모가 없는 아이들이 함께 살아가는 그레이스 필드 하우스. 세상과 단절된 채 살아가...
# 4       나만이 없는 거리  '리바이벌'이라는 시간 이동 능력을 가진 사토루. 그는 자신이 과거에 지나친 사건이...
# ...           ...                                                ...
# 1272       시크릿 가든  무술감독을 꿈꾸는 스턴트우먼 길라임과 까칠한 백화점 사장 김주원. 의도치 않게 영혼...
# 1273    티파니에서 아침을  신분 상승을 꿈꾸며 티파니 보석상을 활보하는 여인 홀리. 같은 아파트에 사는 가난한...
# 1274  신의 선물 - 14일  유괴범에게 딸을 잃은지 14일 전으로 타임워프 된 방송작가 수현. 14일 안에 범인...
# 1275        더 콘서트  유대인 연주자들을 몰아내라는 당의 지시를 어겨 지휘를 그만두게 된 안드레이. 음악에...
# 1276         록키 3  승승장구하던 록키는 자만심과 매너리즘에 빠져 관장 믹키와 다툰다. 강력한 복서 클러...
#
#                       rating  \
# 0     예상 별점\n3.9\n평균 별점\n4.0
# 1     예상 별점\n3.5\n평균 별점\n4.0
# 2     예상 별점\n3.5\n평균 별점\n3.9
# 3     예상 별점\n4.2\n평균 별점\n4.3
# 4     예상 별점\n4.1\n평균 별점\n4.1
# ...                      ...
# 1272  예상 별점\n4.0\n평균 별점\n4.0
# 1273  예상 별점\n3.6\n평균 별점\n3.8
# 1274  예상 별점\n4.0\n평균 별점\n3.9
# 1275  예상 별점\n3.2\n평균 별점\n3.5
# 1276  예상 별점\n1.9\n평균 별점\n3.5
#
#                                                    info
# 0     개요  판타지 · 애니메이션   |   사랑 · 영상미   |   일본   |   ...
# 1          개요  범죄 · 액션   |   폭력적인   |   한국   |    2017년
# 2     개요  판타지 · 액션   |   워너 브라더스   |   미국 · 독일   |  ...
# 3      개요  애니메이션 · 판타지   |   스릴있는   |   일본   |    2019년
# 4                개요  애니메이션 · 미스터리   |   일본   |    2016년
# ...                                                 ...
# 1272             개요  로맨스 · 로맨틱코미디   |   한국   |    2010년
# 1273  개요  코미디 · 로맨스   |   완성도 · 퍼포먼스   |   미국   |   ...
# 1274     개요  미스터리 · 스릴러   |   연기력   |   한국   |    2014년
# 1275  개요  코미디 · 드라마   |   퍼포먼스   |   프랑스 · 이탈리아   | ...
# 1276  개요  드라마 · 스포츠   |   치열한 · 퍼포먼스   |   미국 · 캐나다 ...
#
# [1277 rows x 4 columns]

# %%
title = list()
story = list()
rating = list()
genre = list()
tag = list()
region = list()
year = list()

rating_regexp = re.compile('\d.\d$')
info_split_regexp = re.compile('\|') 
genre_split_regexp = re.compile('\s\D+[^·]')
year_split_regexp = re.compile('\d+년$')

# %%
for i in df['title']:
    title.append(i)
    
for i in df['story']:
    story.append(i)
    
for i in df['rating']:
    rating.append(rating_regexp.findall(i)[0])
    
for i in df['info']:
    info = info_split_regexp.split(i)
    genre.append("".join(genre_split_regexp.findall(info[0])).strip())
    if len(info) == 3: # tag가 안 붙은 작품
        tag.append("no_tags")
        region.append("".join(genre_split_regexp.findall(info[1])).strip())
        year.append("".join(year_split_regexp.findall(info[2])).strip())
        
    else:
        tag.append("".join(genre_split_regexp.findall(info[1])).strip())
        region.append("".join(genre_split_regexp.findall(info[2])).strip())
        year.append("".join(year_split_regexp.findall(info[3])).strip())

# %%
movie = pd.DataFrame({'title' : title,
                      'story' : story,
                      'rating' : rating,
                      'genre' : genre,
                      'tag' : tag,
                      'region' : region,
                      'year' : year})
movie.iloc[:1,:]
# Out:
#   title                                              story rating  \
# 0  늑대아이  평범한 여대생 하나는 우연히 평범한 사람이 아닌 늑대인간과 사랑에 빠지게 된다. 하...    4.0
#
#          genre       tag region   year
# 0  판타지 · 애니메이션  사랑 · 영상미     일본  2012년

# %%
# profile = ProfileReport(movie)
# profile.to_notebook_iframe()

# %%
movie.to_csv("movies.csv", mode='w', index=False)
